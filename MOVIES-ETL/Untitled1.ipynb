# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('Resources/movies_metadata.csv')
ratings = pd.read_csv('Resources/ratings.csv')
# Out:
# /Users/jazzshie/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 3498357    36448   122886     3.0  1465245013
# 10510278  108515     1962     3.0  1357110348
# 9892259   101908     2581     5.0  1366522347
# 1879383    19522     1372     0.5  1099582068
# 7466174    77016     6377     3.5  1122587591

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 41474  False                   NaN         0
# 42008  False                   NaN         0
# 4482   False                   NaN  20000000
# 20160  False                   NaN         0
# 31239  False                   NaN         0
#
#                                                   genres homepage      id  \
# 41474                  [{'id': 9648, 'name': 'Mystery'}]      NaN  105711
# 42008  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN  417056
# 4482   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN     505
# 20160  [{'id': 10752, 'name': 'War'}, {'id': 99, 'nam...      NaN  288128
# 31239  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN  277237
#
#          imdb_id original_language                  original_title  \
# 41474  tt0038885                en     Ritual in Transfigured Time
# 42008  tt3827684                en                      The Hollow
# 4482   tt0097626                en                 Johnny Handsome
# 20160  tt0373873                en  Great Escape: The Untold Story
# 31239  tt1837574                en                           Hyena
#
#                                                 overview  ... release_date  \
# 41474  A social event choreographed in the manner of ...  ...   1946-01-01
# 42008  When a U.S. congressman's daughter passing thr...  ...   2016-10-07
# 4482   A career criminal who has been deformed since ...  ...   1989-09-12
# 20160  A documentary about the 1944 mass escape from ...  ...   2001-01-01
# 31239  Good policing doesn't necessarily mean doing e...  ...   2014-06-18
#
#          revenue runtime                                   spoken_languages  \
# 41474        0.0    15.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 42008        0.0   128.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4482   7237794.0    94.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 20160        0.0    60.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 31239        0.0   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 41474  Released                                                NaN
# 42008  Released              High-profile murder, low-profile town
# 4482   Released  They changed his looks, his life and his futur...
# 20160  Released                                                NaN
# 31239  Released  There are 33,000 in his gang.  His gang is the...
#
#                                 title  video vote_average vote_count
# 41474     Ritual in Transfigured Time  False          7.8       12.0
# 42008                      The Hollow  False          5.0       14.0
# 4482                  Johnny Handsome  False          6.1       49.0
# 20160  Great Escape: The Untold Story  False          0.0        0.0
# 31239                           Hyena  False          5.3       32.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/15/wcc8ng1x1wzgwlnwp7fchh600000gn/T/ipykernel_7182/808813721.py in <module>
# ----> 1 kaggle_metadata.dtypes
#
# NameError: name 'kaggle_metadata' is not defined
